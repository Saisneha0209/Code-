# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Code-/blob/main/Compound_Interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#formula for compound interest....
#A = P * (1 + R/100) ** T
#CI = A - P
P = float(input("Enter Principal:"))
R= float(input("Enter Rate: "))
T = float(input("Enter Time: "))
A = P * (1 + R/100) * (1 + R/100)  # So here we say like for 2 years...
CI = A - P
print("Compound Interest =", CI)
# Out:
# Enter Principal:45000
# Enter Rate: 45
# Enter Time: 6
# Compound Interest = 49612.5
