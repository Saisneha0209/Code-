# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Code-/blob/main/Ternary_Operator!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TERNARY OPERATOR!!

# %%
#Using Ternary Operator!
m =int(input("Enter your marks:"))
x="A" if m>=90 else "B" if m>=70 else "C" if m>=60 else "D" if m>=40 else"Fail"
print(x)

# %%
#for weekend prpgram!!
day=input("enter the day:")
x="weekend"if day=="sunday" and "saturday" else "non weekend"
print(x)
# Out:
# enter the day:sunday
# weekend
